# %%
from database.DB_query import statistics_database, get_valid_rows
from cfg.safesession import *
stat = statistics_database(session)
rows = get_valid_rows(session)

# %% [markdown]
# # Meta-data Stat

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-v0_8')

# 
plt.figure(figsize=(3, 2), dpi=300)

# 
data = stat['years']#[row.publication_date.year for row in rows]
#  bin edges bin 
#  bin edges bin
bin_edges = np.arange(min(data)-0.5, max(data)+0.5, 1)
# 
plt.hist(data, bins=bin_edges , edgecolor='steelblue', color='steelblue', alpha=0.7, align='mid')  # Set align to 'mid'

# 
plt.xlabel('Publication Year')
plt.ylabel('Number of Reviews')
# 
plt.tick_params(which='both', direction='in', length=1, width=0.5)
# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()

# 
plt.savefig('pub_year.svg')

# 
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

# 
data = stat['ref_counts']
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 
plt.hist(data, bins=45,  edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of References in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel('Number of References')
plt.ylabel('Number of Reviews')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
# plt.legend(['Number of Reviews'])
plt.savefig('ref_counts.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

# 
data = stat['citation_counts']
# bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 
plt.hist(data, bins=2000, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Citation Counts in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)
plt.xscale('log')
# 
plt.xlabel('Number of Received Citations')
plt.ylabel('Number of Reviews')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig('citation_counts.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

# 
data = stat['authors_num']
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel('Number of Authors')
plt.ylabel('Number of Reviews')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig('authors_num.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

prop = 'Words Count'
data = [row.word_count for row in rows if row.word_count]#stat[prop]
print(len(data))
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1800)
# 
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel(prop)
plt.ylabel('Number of Words')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig(f'{prop}.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

prop = 'Pages Count'
data = [row.paper_num_pages for row in rows if row.paper_num_pages]#stat[prop]
print(len(data))
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 2)
# 
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel(prop)
plt.ylabel('Number of Pages')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig(f'{prop}.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

prop = 'Figures Count'
data = [row.num_figs for row in rows if row.num_figs is not None]#stat[prop]
print(len(data))
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel(prop)
plt.ylabel('Number of Figures')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig(f'{prop}.svg')
# 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8')
# 
plt.figure(figsize=(3, 2), dpi=300)

prop = 'Tables Count'
data = [row.num_tabs for row in rows if row.num_tabs is not None]#stat[prop]
print(len(data))
bin_edges = np.arange(min(data)-0.5, max(data)+0.5, 1)
# 
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 
plt.xlabel(prop)
plt.ylabel('Number of Tables')

# 
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 
plt.tight_layout()
plt.savefig(f'{prop}.svg')
# 
plt.show()
