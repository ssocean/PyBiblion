# %% [markdown]
# # 统计数据库

# %%
from sqlalchemy.ext.declarative import declarative_base

from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy.orm import sessionmaker

Base = declarative_base()

# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()

# %%
from database.query_info import statistics_database

stat = statistics_database(session)
# Out:
# 100%|██████████| 3532/3532 [00:00<00:00, 353183.50it/s]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-paper')

# 示例数据
data = stat['years']

# 绘制直方图
plt.hist(data, bins=50, edgecolor='black')

# 添加标签和标题
plt.xlabel('Publication Year')
plt.ylabel('Number of Reviews')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-paper')
# 示例数据
data = stat['ref_counts']

# 绘制直方图
plt.hist(data, bins=1000, edgecolor='black')

# 添加标签和标题
plt.xlabel('References')
plt.ylabel('Number of Reviews')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-paper')
# 示例数据
data = stat['citation_counts']

# 绘制直方图
plt.hist(data, bins=1000, edgecolor='black')

# 添加标签和标题
plt.xlabel('Value')
plt.ylabel('Number of Reviews')


# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-paper')
# 示例数据
data = stat['authors_num']

# 绘制直方图
plt.hist(data, bins=1000, edgecolor='black')

# 添加标签和标题
plt.xlabel('Value')
plt.ylabel('Number of Reviews')


# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-v0_8')

# 设置图像大小和分辨率
plt.figure(figsize=(3, 2), dpi=300)

# 示例数据
data = stat['years']
# 计算直方图的 bin edges，使得每个 bin 有相等的宽度
# 计算直方图的 bin edges，每个年份对应一个 bin
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 绘制直方图
plt.hist(data, bins=bin_edges , edgecolor='steelblue', color='steelblue', alpha=0.7, align='mid')  # Set align to 'mid'

# 添加轴标签
plt.xlabel('Publication Year')
plt.ylabel('Number of Reviews')
# 设置所有刻度可见
plt.tick_params(which='both', direction='in', length=1, width=0.5)
# 调整刻度字体大小
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 调整边框颜色和粗细
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 调整图表间距
plt.tight_layout()

# 保存图像
plt.savefig('pub_year.svg')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 设置图像大小和分辨率
plt.figure(figsize=(3, 2), dpi=300)

# 示例数据
data = stat['ref_counts']
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 绘制直方图
plt.hist(data, bins=45,  edgecolor='steelblue', color='steelblue', alpha=0.7)

# 添加标题和注释
# plt.title('Distribution of References in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 添加轴标签
plt.xlabel('Number of References')
plt.ylabel('Number of Reviews')

# 调整刻度和标签
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 调整边框颜色和粗细
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 调整图表间距
plt.tight_layout()
# plt.legend(['Number of Reviews'])
plt.savefig('ref_counts.svg')
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 设置图像大小和分辨率
plt.figure(figsize=(3, 2), dpi=300)

# 示例数据
data = stat['citation_counts']
# bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 绘制直方图
plt.hist(data, bins=10000, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 添加标题和注释
# plt.title('Distribution of Citation Counts in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)
plt.xscale('log')
# 添加轴标签
plt.xlabel('Number of Received Citations')
plt.ylabel('Number of Reviews')

# 调整刻度和标签
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 调整边框颜色和粗细
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 调整图表间距
plt.tight_layout()
plt.savefig('citation_counts.svg')
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# 设置图像大小和分辨率
plt.figure(figsize=(3, 2), dpi=300)

# 示例数据
data = stat['authors_num']
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)
# 绘制直方图
plt.hist(data, bins=bin_edges, edgecolor='steelblue', color='steelblue', alpha=0.7)

# 添加标题和注释
# plt.title('Distribution of Number of Authors in Reviews')
# plt.text(0.5, 0.95, 'Data Source: Your Source', ha='center', va='center', transform=plt.gca().transAxes)

# 添加轴标签
plt.xlabel('Number of Authors')
plt.ylabel('Number of Reviews')

# 调整刻度和标签
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 调整边框颜色和粗细
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 调整图表间距
plt.tight_layout()
plt.savefig('authors_num.svg')
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 示例数据
data = stat['ref_counts']
bin_edges = np.arange(min(data)-0.5, max(data)+1.5, 1)

# 绘制直方图
plt.hist(data, bins=45,  edgecolor='steelblue', color='steelblue', alpha=0.7)

# 计算均值和中位数
mean_value = np.mean(data)
median_value = np.median(data)

# 绘制均值和中位数的垂直线
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label='Median')

# 添加轴标签
plt.xlabel('Number of References')
plt.ylabel('Number of Reviews')

# 调整刻度和标签
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# 显示均值和中位数的数值
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")

# 调整边框颜色和粗细
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

# 添加图例
plt.legend()

# 调整图表间距
plt.tight_layout()

# 保存图像
plt.savefig('ref_counts_with_mean_median.svg')

# 显示图形
plt.show()
# Out:
# Mean: 139.72759103641457
# Median: 123.0

# %%
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast

from tqdm import tqdm

from database.DBEntity import PaperMapping
from furnace.arxiv_paper import Arxiv_paper

from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()

def get_median_pubdate(pub_time,refs):
    pub_dates = []
    for i in refs:
        if i.publication_date:
            pub_dates.append(i.publication_date)
    # pub_dates = [i.publication_date for i in s2paper.references]
    sorted_list = sorted(pub_dates, reverse=True)
    index = 0
    while index < len(sorted_list):
        try:
            sorted_list[index].timestamp()
            index += 1
        except Exception as e:
            print(f"Error: {e}")
            del sorted_list[index]

    timestamps = [d.timestamp() for d in sorted_list]
    if len(timestamps) == 0:
        return float('-inf')
    median_timestamp = statistics.median(timestamps)
    median_value = datetime.datetime.fromtimestamp(median_timestamp)

    # median_value = statistics.median(sorted_list)
    months_difference = (pub_time - median_value) // datetime.timedelta(days=30)
    return months_difference

# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
for row in tqdm(results):
    references = []
    # s2paper = S2paper(row.title)
    # row.reference_details =  s2paper.references
    ref_list = ast.literal_eval(row.reference_details)
    # ref_detail = json.loads(row.reference_details)
    
    temp = get_median_pubdate(row.publication_date,ref_list)
    med_pub_dates.append(temp)
# Out:
#   0%|          | 14/3532 [00:00<00:54, 64.55it/s]
# Error: [Errno 22] Invalid argument
# ethical dimensions for data quality
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
#   1%|          | 27/3532 [00:00<01:19, 44.29it/s]
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
#   1%|          | 41/3532 [00:00<01:02, 55.51it/s]
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
# Error: [Errno 22] Invalid argument
#   2%|▏         | 55/3532 [00:01<01:01, 56.68it/s]
# ...

# %%
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast

from tqdm import tqdm

from database.DBEntity import PaperMapping
from furnace.arxiv_paper import Arxiv_paper

from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()

def get_median_pubdate(pub_time,refs):
    pub_dates = []
    for i in refs:
        if i.publication_date:
            pub_dates.append(i.publication_date)
    # pub_dates = [i.publication_date for i in s2paper.references]
    sorted_list = sorted(pub_dates, reverse=True)
    index = 0
    while index < len(sorted_list):
        try:
            sorted_list[index].timestamp()
            index += 1
        except Exception as e:
            print(f"Error: {e}")
            del sorted_list[index]

    timestamps = [d.timestamp() for d in sorted_list]
    if len(timestamps) == 0:
        return float('-inf')
    median_timestamp = statistics.median(timestamps)
    median_value = datetime.datetime.fromtimestamp(median_timestamp)

    # median_value = statistics.median(sorted_list)
    months_difference = (pub_time - median_value) // datetime.timedelta(days=30)
    return months_difference

# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
tn = 0

for row in tqdm(results):
    
    if row.is_review == 1 and row.valid == 1:
        
        references = []
        # s2paper = S2paper(row.title)
        # row.reference_details =  s2paper.references
        # response = row.reference_details
        try:
            ref_detail = json.loads(row.reference_details)
            if 'data' not in ref_detail:
                continue
            for item in ref_detail['data']:
                # print(item)
                ref = S2paper(item['citedPaper']['title'])
                ref.filled_authors = False
                info = {'paperId': item['citedPaper']['paperId'], 'contexts': item['contexts'],
                        'intents': item['intents'], 'isInfluential': item['isInfluential'],
                        'title': item['citedPaper']['title'], 'venue': item['citedPaper']['venue'],
                        'citationCount': item['citedPaper']['citationCount'],
                        'influentialCitationCount': item['citedPaper']['influentialCitationCount'],
                        'publicationDate': item['citedPaper']['publicationDate']}
                # authors = []

                ref._entity = info
                # print(ref.citation_count)
                references.append(ref)
            tn+=1
            temp = get_median_pubdate(row.publication_date,references)
            med_pub_dates.append(temp)
        except:
            
            continue

print(tn)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 59
#      57 Session = sessionmaker(bind=engine)
#      58 session = Session()
# ---> 59 results = session.query(PaperMapping).all()
#      60 med_pub_dates = []
#      61 # random.shuffle(results)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\query.py:2768, in Query.all(self)
#    2752 def all(self):
#    2753     """Return the results represented by this :class:`_query.Query`
#    2754     as a list.
#    2755
#    (...)
#    2766             :ref:`faq_query_deduplicating`
#    2767     """
# -> 2768     return self._iter().all()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\query.py:2903, in Query._iter(self)
#    2900 params = self._params
#    2902 statement = self._statement_20()
# -> 2903 result = self.session.execute(
#    2904     statement,
#    2905     params,
# ...

# %%
import ast

str_data = "[{'intents': ['methodology'], 'isInfluential': False}]"

# 将字符串转换为Python对象
python_data = ast.literal_eval(str_data)

# %%
python_data
# Out:
# [{'intents': ['methodology'], 'isInfluential': False}]

# %%
med_pub_dates
# Out:
# [82,
#  35,
#  69,
#  42,
#  53,
#  0,
#  66,
#  27,
#  38,
#  18,
#  33,
#  33,
#  27,
#  19,
#  9,
#  41,
#  28,
#  13,
#  35,
#  82,
#  66,
#  40,
#  79,
#  32,
#  53,
#  51,
#  48,
#  56,
#  24,
#  57,
#  33,
#  14,
#  88,
#  45,
#  16,
#  64,
#  38,
#  14,
#  35,
#  40,
#  24,
#  46,
#  29,
#  33,
#  16,
#  62,
#  37,
#  -inf,
#  42,
#  36,
#  101,
#  29,
#  58,
#  50,
#  81,
#  43,
#  59,
#  8,
#  53,
#  31,
#  49,
#  78,
#  47,
#  43,
#  82,
#  112,
#  38,
#  29,
#  42,
#  67,
#  30,
#  48,
#  64,
#  27,
#  35,
#  39,
#  28,
#  17,
#  26,
#  26,
#  51,
#  41,
#  39,
#  29,
#  112,
#  45,
#  65,
#  68,
#  54,
#  37,
#  45,
#  63,
#  26,
#  106,
#  30,
#  12,
#  39,
#  56,
#  32,
#  18,
#  81,
#  16,
#  37,
#  38,
#  58,
#  35,
#  27,
#  49,
#  66,
#  53,
#  40,
#  191,
#  35,
#  60,
#  42,
#  56,
#  35,
#  46,
#  10,
#  20,
#  15,
#  42,
#  34,
#  25,
#  54,
#  22,
#  86,
#  61,
#  109,
#  42,
#  57,
#  40,
#  104,
#  46,
#  7,
#  49,
#  44,
#  53,
#  20,
#  30,
#  17,
#  62,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 原始数组
data = med_pub_dates

# 过滤掉 -inf 值
filtered_data = [x for x in data if x != -float('inf') and x >= 0]
# 计算均值和中位数
mean_value = np.mean(filtered_data)
median_value = np.median(filtered_data)

# 绘制均值和中位数的垂直线
plt.axvline(mean_value, color='r', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(median_value, color='g', linestyle='dashed', linewidth=1, label='Median')
print(f'mean:{mean_value}, med:{median_value}')
# 绘制直方图
plt.hist(filtered_data, bins='auto', alpha=0.7, rwidth=0.85)

# 设置标题和坐标轴标签
plt.title("Histogram of Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
# 显示图形
plt.show()
# Out:
# mean:48.55797610681658, med:41.0

# %%
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast

from tqdm import tqdm

from database.DBEntity import PaperMapping
from furnace.arxiv_paper import Arxiv_paper

from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()

def get_median_pubdate(pub_time,refs):
    pub_dates = []
    for i in refs:
        if i.publication_date:
            pub_dates.append(i.publication_date)
    # pub_dates = [i.publication_date for i in s2paper.references]
    sorted_list = sorted(pub_dates, reverse=True)
    index = 0
    while index < len(sorted_list):
        try:
            sorted_list[index].timestamp()
            index += 1
        except Exception as e:
            print(f"Error: {e}")
            del sorted_list[index]

    timestamps = [d.timestamp() for d in sorted_list]
    if len(timestamps) == 0:
        return float('-inf')
    median_timestamp = statistics.median(timestamps)
    median_value = datetime.datetime.fromtimestamp(median_timestamp)

    # median_value = statistics.median(sorted_list)
    months_difference = (pub_time - median_value) // datetime.timedelta(days=30)
    return months_difference

# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
tn = 0

for row in tqdm(results):
    
    if row.is_review == 1 and row.valid == 1:
        
        references = []
        # s2paper = S2paper(row.title)
        # row.reference_details =  s2paper.references
        # response = row.reference_details
        try:
            ref_detail = json.loads(row.reference_details)
            if 'data' not in ref_detail:
                continue
            for item in ref_detail['data']:
                # print(item)
                ref = S2paper(item['citedPaper']['title'])
                ref.filled_authors = False
                info = {'paperId': item['citedPaper']['paperId'], 'contexts': item['contexts'],
                        'intents': item['intents'], 'isInfluential': item['isInfluential'],
                        'title': item['citedPaper']['title'], 'venue': item['citedPaper']['venue'],
                        'citationCount': item['citedPaper']['citationCount'],
                        'influentialCitationCount': item['citedPaper']['influentialCitationCount'],
                        'publicationDate': item['citedPaper']['publicationDate']}
                # authors = []

                ref._entity = info
                # print(ref.citation_count)
                references.append(ref)
            tn+=1
            temp = get_median_pubdate(row.publication_date,references)
            med_pub_dates.append(temp)
        except:
            
            continue

print(tn)

# %%
data = stat['citation_counts']

# %% [markdown]
# # 计算引用的均值 标准差

# %%
from datetime import timedelta
from collections import OrderedDict
from tools.ref_utils import get_s2citaions_per_month
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast

from tqdm import tqdm

from database.DBEntity import PaperMapping, CoP
from furnace.arxiv_paper import Arxiv_paper
import numpy as np
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()



# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
tn = 0
from datetime import datetime
means = []
stds = []
citation_count = {}
for row in tqdm(results):
    if row.is_review == 1 and row.valid == 1 and row.s2_citation_count:
        if row.s2_citation_count >=86 and row.s2_citation_count<=356:
            tn += 1
            match = session.query(CoP).filter_by(s2_id=row.s2_id).one()
            
            # print(match.citation)
            r = json.loads(match.citation)[0]
            if 'data' not in r:
                continue
            # print(r.json()['data'])
            for item in r['data']:
                # print(item)
                info = {'paperId': item['citingPaper']['paperId'], 'title': item['citingPaper']['title'],
                        'citationCount': item['citingPaper']['citationCount'],
                        'publicationDate': item['citingPaper']['publicationDate']}
                ref = S2paper(info, ref_type='entity')
                ref.filled_authors = False
                try:
                    if row.s2_publication_date <= ref.publication_date and ref.publication_date <= datetime.now():
                        dict_key = str(ref.publication_date.year) + '.' + str(ref.publication_date.month)
                        citation_count.update({dict_key: citation_count.get(dict_key, 0) + 1})
                except Exception as e:
                    print(e)
            sorted_data = OrderedDict(sorted(citation_count.items(), key=lambda x: datetime.strptime(x[0], "%Y.%m"), reverse=True))

            latest_month = datetime.now()#.strptime(s2paper.publication_date, "%Y.%m")# datetime.now().strftime("%Y.%m")
            earliest_month = row.s2_publication_date#.strftime("%Y.%m")#datetime.strptime(s2paper.publication_date, "%Y.%m")

            # 创建包含所有月份的列表
            all_months = [datetime.strftime(latest_month, "%Y.%#m")]
            while latest_month > earliest_month:
                latest_month = latest_month.replace(day=1)  # 设置为月初
                latest_month = latest_month - timedelta(days=1)  # 上一个月
                all_months.append(datetime.strftime(latest_month, "%Y.%#m"))
        
            # 对缺失的月份进行补0
            result = {month: sorted_data.get(month, 0) for month in all_months}
            # 将字典按照时间从最近到最远排序
            result = OrderedDict(sorted(result.items(), key=lambda x: datetime.strptime(x[0], "%Y.%m"), reverse=True))

    # 遍历结果并处理
    # for result in results:
    #     # 处理每个结果对象
    #     print(result.column1, result.column2)  # 假设有名为 column1、column2 的列
            spms = result
            if len(spms) > 0:
                data = list(spms.values())
                data = [i+1 for i in data]
                # 计算 ln 均值和标准差
                ln_data = np.log(data)
                ln_mean = np.mean(ln_data)
                ln_std = np.std(ln_data)
                means.append(ln_mean)
                stds.append(ln_std)
# Out:
#   0%|          | 11/3532 [00:00<00:00, 11000.80it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 61
#      56 # print(r.json()['data'])
#      57 for item in r['data']:
#      58     # print(item)
#      59     info = {'paperId': item['citingPaper']['paperId'], 'title': item['citingPaper']['title'],
#      60             'citationCount': item['citingPaper']['citationCount'],
# ---> 61             'publicationDate': item['citingPaper']['publicationDate']}
#      62     ref = S2paper(info, ref_type='entity')
#      63     ref.filled_authors = False
#
# KeyError: 'publicationDate'

# %%
from datetime import timedelta
from collections import OrderedDict
from tools.ref_utils import get_s2citaions_per_month
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast
import matplotlib.pyplot as plt
from tqdm import tqdm

from database.DBEntity import PaperMapping, CoP
from furnace.arxiv_paper import Arxiv_paper
import numpy as np
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()



# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
tn = 0
from datetime import datetime
means = []
stds = []
cite_per_month = []
citation_count = {}
plt.figure(figsize=(10, 6))
for row in tqdm(results):
    if row.is_review == 1 and row.valid == 1 and row.s2_citation_count:
        if int(row.publication_date.year)>= 2015 and int(row.publication_date.year)<= 2017: # row.s2_citation_count >=12 and

            spms = get_s2citaions_per_month(row.title,10000)
            if len(spms) >= 72:
                tn += 1
                data = list(spms.values())[:72]
                data = [sum(data[i:i+12]) for i in range(0, len(data), 12)]
                # print(len(data))
                
                plt.plot(data, marker='o')
                plt.title(f'Citations Per Month for {row.title}')
                plt.xlabel('Months')
                plt.ylabel('Citations')
                plt.grid(True)
                plt.savefig(rf'C:\Users\Ocean\Desktop\savefig\{tn}.png')
                # plt.show()
                plt.clf()
                cite_per_month.append(data)
                data = [i+1 for i in data]
                # 计算 ln 均值和标准差
                ln_data = np.log(data)
                ln_mean = np.mean(ln_data)
                ln_std = np.std(ln_data)
                # print(ln_mean,ln_std)
                means.append(ln_mean)
                stds.append(ln_std)
# Out:
#  12%|█▏        | 407/3532 [00:11<01:24, 36.99it/s]
# spatio-temporal analysis of team sports
# NO PUBLICATION DATE RECORDER
# C:\Users\Ocean\AppData\Local\Temp\ipykernel_27004\2535230614.py:57: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 6))
#  18%|█▊        | 619/3532 [00:16<01:09, 42.17it/s]
# exploiting ais data for intelligent maritime navigation: a comprehensive survey from data to methodology
# NO PUBLICATION DATE RECORDER
#  21%|██        | 733/3532 [00:22<01:44, 26.84it/s]
# a survey on feature selection methods
# NO PUBLICATION DATE RECORDER
# retrieving
#  30%|███       | 1062/3532 [00:32<01:14, 33.29it/s]
# retrieving
# retrieving
# ...

# %%
from statistics import mean
mu = mean(means)  # 平均值
sigma = mean(stds)  # 标准差
print(mu,sigma)
# Out:
# 2.1313108652463253 0.4287341744860236

# %%
total_cite = np.sum(np.array(cite_per_month), axis=0)
total_cite = total_cite/len(cite_per_month) + 0.3
print(total_cite)
# Out:
# [23.23157895 26.24210526 27.44736842 32.61578947 26.97368421 19.03157895]

# %%
cite_per_month_np = np.array(cite_per_month) + 1
cite_per_month_np
# Out:
# array([[ 1,  1,  2,  3,  4,  1],
#        [ 1,  1,  1,  1,  1,  2],
#        [ 6,  3,  4,  8,  2, 11],
#        ...,
#        [ 1,  1,  2,  1,  4,  1],
#        [ 1,  1,  1,  1,  3,  2],
#        [17,  9, 12, 10,  2,  1]])

# %%
# 通过将每一行除以该行的最大值来归一化
norm_CPM = (cite_per_month_np - cite_per_month_np.min(axis=1, keepdims=True) )/ cite_per_month_np.max(axis=1, keepdims=True)

# 计算归一化数据每一列的均值
norm_CPM  = norm_CPM.mean(axis=0)

# %%
norm_CPM
# Out:
# array([0.17118259, 0.24091411, 0.30022443, 0.39930136, 0.3651375 ,
#        0.26175548])

# %%
ln_data = np.log(total_cite)
ln_mean = np.mean(ln_data)
ln_std = np.std(ln_data)
print(total_cite)
print(ln_data)
print(ln_mean)
print(ln_std)
# Out:
# [13.45740741 17.12407407 18.57777778 25.02222222 23.8        21.67962963
#  17.16111111 12.64259259]
# [2.59952969 2.84048531 2.92196612 3.21976432 3.16968558 3.07637309
#  2.84264584 2.53707148]
# 2.900940180101056
# 0.2332899095222124

# %%
import numpy as np
import matplotlib.pyplot as plt

def sum_and_plot(arr):
    """
    Sums the elements of a 2D array along the first dimension and plots the result.

    Parameters:
    arr (np.array): A 2D numpy array where each sub-array contains 24 elements.

    Returns:
    None
    """
    # Summing along the first dimension
    summed_array = arr#np.sum(arr, axis=0)

    # Plotting the result
    plt.figure(figsize=(10, 6))
    plt.plot(summed_array, marker='o', linestyle='-')
    plt.title("Summed Array Elements")
    plt.xlabel("Element Index")
    plt.ylabel("Summed Value")
    plt.grid(True)
    plt.show()

# Example usage
# Create a sample 2D array with random values
# np.random.seed(0)  # For reproducibility
total_array = norm_CPM#np.array(total_cite)  # 5 arrays, each containing 24 elements

# Call the function with this sample array
sum_and_plot(total_array)
print(total_array)
ln_total_array = np.log(total_array)
print(np.mean(ln_total_array),np.std(ln_total_array))
# Out:
# [0.17118259 0.24091411 0.30022443 0.39930136 0.3651375  0.26175548]
# -1.2762381555024003 0.28003605924908925

# %%
# Provided data
x_data = np.arange(len(list(total_array))+1)  # x values (0 to 7)
y_data = np.array([0]+list(total_array))

# Perform polynomial fitting
# We can start with a 3rd-degree polynomial and adjust if necessary
degree = 3
coefficients = np.polyfit(x_data, y_data, degree)
print(coefficients)
# Create a polynomial function with the fitted coefficients
polynomial_function = np.poly1d(coefficients)

# Generate fitted data
fitted_y_data = polynomial_function(x_data)

# Display the polynomial coefficients

# Plot the original data and the polynomial fitted curve
plt.figure(figsize=(10, 6))
plt.plot(x_data, y_data, 'bo', label='Original Data')
plt.plot(x_data, fitted_y_data, 'r-', label='Polynomial Fitted Curve')
plt.title("Polynomial Fit to the Data")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# [-0.0025163   0.00106611  0.12671325  0.01288683]

# %%
# Convert the fitted curve to a probability density function (PDF)
# Ensure the area under the curve sums up to 1
x_pdf = np.linspace(0, 7.3, 200)  # extended range for PDF
fitted_y_pdf = polynomial_function(x_pdf)
pdf_normalized = fitted_y_pdf / np.trapz(fitted_y_pdf, x_pdf)

# Plot the PDF
plt.figure(figsize=(10, 6))
plt.plot(x_pdf, pdf_normalized, 'g-', label='Probability Density Function')
plt.title("Probability Density Function of the Polynomial Fit")
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %%
from scipy.integrate import cumtrapz
def get_RAD(M_pc):
    x = M_pc/12
    coefficients= np.array([-0.0025163,0.00106611, 0.12671325, 0.01288683])
    
    polynomial_function = np.poly1d(coefficients)
    x_pdf = np.linspace(0, 7.36, 200)  # extended range for PDF
    fitted_y_pdf = polynomial_function(x_pdf)
    pdf_normalized = fitted_y_pdf / np.trapz(fitted_y_pdf, x_pdf)


    # Compute the cumulative probability distribution function (CDF)
    cdf = cumtrapz(pdf_normalized, x_pdf, initial=0)
    cdf = np.where(cdf > 1.0, 1.0, cdf)
    # If x is less than the minimum x value in x_pdf, return 0 (assuming CDF is 0 at negative infinity)
    if x < x_pdf[0]:
        return 0

    # If x is greater than the maximum x value in x_pdf, return 1 (CDF is 1 at positive infinity)
    if x > x_pdf[-1]:
        return 1
    
    # Find the index in x_pdf that is closest to x
    index = np.searchsorted(x_pdf, x, side="left")
    
    # Return the corresponding CDF value
    return cdf[index]

get_RAD(84)
# Out:
# 0.9922593934964093

# %%
import statistics

# %%
median_value = statistics.median(stat['citation_counts'])
mean(stat['citation_counts'])
# Out:
# 86.37809917355372

# %%
# Out:
# array([7.36011009, 7.36011009, 7.36011009])

# %%
cdf = cumtrapz(pdf_normalized, x_pdf, initial=0)

# Plot the CDF
plt.figure(figsize=(10, 6))
plt.plot(x_pdf, cdf, 'b-', label='Cumulative Probability Distribution')
plt.title("Cumulative Probability Distribution of the Polynomial Fit")
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.show()

# %%
def calculate_cdf_value_extended(x, x_pdf, cdf):
    """
    Calculate the CDF value for a given x, with extensions beyond the original domain.

    :param x: The x value for which to find the CDF value.
    :param x_pdf: Array of x values used in the CDF computation.
    :param cdf: Array of CDF values corresponding to x_pdf.
    :return: CDF value for the given x. Returns 1 for values beyond the maximum x_pdf.
    """
    cdf = np.where(cdf > 1.0, 1.0, cdf)
    # If x is less than the minimum x value in x_pdf, return 0 (assuming CDF is 0 at negative infinity)
    if x < x_pdf[0]:
        return 0

    # If x is greater than the maximum x value in x_pdf, return 1 (CDF is 1 at positive infinity)
    if x > x_pdf[-1]:
        return 1
    
    
    # Find the index in x_pdf that is closest to x
    index = np.searchsorted(x_pdf, x, side="left")
    
    # Return the corresponding CDF value
    return cdf[index]

# Example: Calculate the CDF value for a specific x, extended beyond the original domain
x_value_extended =7  # Example value beyond the original domain
cdf_value_at_x_extended = calculate_cdf_value_extended(x_value_extended, x_pdf, cdf)
cdf_value_at_x_extended
# Out:
# 0.9915558708950271

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Updated parameters for the log-normal distributions
mu1_updated, sigma1_updated = 1.2, 0.3
mu2_updated, sigma2_updated = 1.07, 0.68

# Create a range of x values
x = np.linspace(0, 5, 1000)

# Calculate the log-normal distribution for the updated parameters
pdf1_updated = lognorm.pdf(x, s=sigma1_updated, scale=np.exp(mu1_updated))
pdf2_updated = lognorm.pdf(x, s=sigma2_updated, scale=np.exp(mu2_updated))

# Plotting the updated distributions
plt.figure(figsize=(10, 6))
plt.plot(x, pdf1_updated, label='μ = 1.2, σ = 0.3')
plt.plot(x, pdf2_updated, label='μ = 1.07, σ = 0.67')
plt.title('Updated Log-Normal Distributions')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm
from statistics import mean


# 设置参数
mu = 2.9  # 平均值
sigma = 0.23  # 标准差

# 定义对数正态分布对象
lognorm_dist = lognorm(sigma, scale=np.exp(mu))

# 生成 x 值
x = np.linspace(0, 50, 1000)

# 计算对应的累积分布函数（CDF）值
cdf = lognorm_dist.cdf(x)

# 绘制积分图像
plt.plot(x, cdf, 'b-', lw=2)

# 设置图形标题和轴标签
plt.title('Integral of Log Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# 设置随机数种子以保持重现性
np.random.seed(42)

# 生成对数正态分布的随机样本
mu = 1.2
sigma = 0.4
mu = 2.9
sigma = 0.23
samples = np.random.lognormal(mu, sigma, 10000)
print(samples)
# 绘制直方图
plt.hist(samples, bins=50, density=True, alpha=0.7, color='skyblue')

# 绘制概率密度函数的曲线
x = np.linspace(0, 24, 1000)
pdf = lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r-', lw=2)

# 设置图形标题和轴标签
plt.title('Log Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')

# 显示图形
plt.show()

# %%
import json
import datetime
import statistics
from furnace.semantic_scholar_paper import S2paper
import os
import re
import ast

from tqdm import tqdm

from database.DBEntity import PaperMapping
from furnace.arxiv_paper import Arxiv_paper

from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from furnace.arxiv_paper import Arxiv_paper
from furnace.google_scholar_paper import Google_paper
from tools.gpt_util import *
import random
Base = declarative_base()

def get_median_pubdate(pub_time,refs):
    pub_dates = []
    for i in refs:
        if i.publication_date:
            pub_dates.append(i.publication_date)
    # pub_dates = [i.publication_date for i in s2paper.references]
    sorted_list = sorted(pub_dates, reverse=True)
    index = 0
    while index < len(sorted_list):
        try:
            sorted_list[index].timestamp()
            index += 1
        except Exception as e:
            print(f"Error: {e}")
            del sorted_list[index]

    timestamps = [d.timestamp() for d in sorted_list]
    if len(timestamps) == 0:
        return float('-inf')
    median_timestamp = statistics.median(timestamps)
    median_value = datetime.datetime.fromtimestamp(median_timestamp)

    # median_value = statistics.median(sorted_list)
    months_difference = (pub_time - median_value) // datetime.timedelta(days=30)
    return months_difference

# 创建数据库引擎
engine = create_engine('mysql+mysqlconnector://root:xxxx@localhost/ripami')

# 创建数据库表
Base.metadata.create_all(engine)

# 创建会话
Session = sessionmaker(bind=engine)
session = Session()
results = session.query(PaperMapping).all()
med_pub_dates = []
# random.shuffle(results)
k = 0
for row in tqdm(results):
    if row.is_review == 1 and row.valid == 1:
        k+=1
print(k)
# Out:
# 100%|██████████| 3532/3532 [00:00<00:00, 1181550.62it/s]
# 2904

# %%
import matplotlib.pyplot as plt

# Years and Data
years = list(range(2010, 2024))
image_classification = [131, 166, 183, 259, 313, 383, 460, 656, 891, 1280, 2090, 3290, 4060, 5170]
image_segmentation = [286, 311, 421, 545, 651, 710, 841, 895, 1100, 1320, 2050, 2930, 3720, 4700]
object_detection = [115, 141, 189, 232, 260, 368, 445, 508, 629, 1070, 1650, 2620, 3370, 4560]
image_generation = [55, 75, 83, 93, 86, 96, 114, 123, 144, 230, 340, 495, 767, 1290]
text_classification = [56, 67, 88, 117, 160, 171, 207, 277, 311, 437, 696, 1020, 1290, 1650]
machine_translation = [88, 95, 125, 127, 145, 167, 195, 259, 365, 517, 815, 1110, 1480, 2030]
question_answering = [74, 95, 120, 113, 139, 146, 168, 187, 274, 358, 464, 674, 851, 1430]
sentiment_analysis = [36, 61, 103, 114, 201, 266, 352, 472, 675, 797, 1280, 1840, 2170, 3250]

# Marker styles for each line
marker_styles = ['o', 's', '^', 'D', '*', 'P', 'X', 'v']

# Plotting
plt.figure(figsize=(12, 8))

for i, (field, marker) in enumerate(zip([image_classification, image_segmentation, object_detection,
                                         image_generation, text_classification, machine_translation,
                                         question_answering, sentiment_analysis], marker_styles)):
    plt.plot(years, field, label=f'Field {i+1}', marker=marker, markersize=8)

# Adding labels and title
plt.xlabel('Years')
plt.ylabel('Number of Papers')
plt.title('Trends in AI Research (2010-2023)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
